# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 220px; height: 150px; vertical-align: middle;">
#             <img src="../assets/aaa.png" width="220" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Autonomous Traders</h2>
#             <span style="color:#ff7800;">An equity trading simulation to illustrate autonomous agents powered by tools and resources from MCP servers.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Week 6 Day 4
#
# And now - introducing the Capstone project:
#
#
# # Autonomous Traders
#
# An equity trading simulation, with 4 Traders and a Researcher, powered by a slew of MCP servers with tools & resources:
#
# 1. Our home-made Accounts MCP server (written by our engineering team!)
# 2. Fetch (get webpage via a local headless browser)
# 3. Memory
# 4. Brave Search
# 5. Financial data
#
# And a resource to read information about the trader's account, and their investment strategy.
#
# The goal of today's lab is to make a new python module, `traders.py` that will manage a single trader on our trading floor.
#
# We will experiment and explore in the lab, and then migrate to a python module when we're ready.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">One more time --</h2>
#             <span style="color:#ff7800;">Please do not use this for actual trading decisions!!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
import os
from dotenv import load_dotenv
from agents import Agent, Runner, trace, Tool
from agents.mcp import MCPServerStdio
from IPython.display import Markdown, display
from datetime import datetime
from accounts_client import read_accounts_resource, read_strategy_resource
from accounts import Account

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Let's start by gathering the MCP params for our trader

# %%
polygon_api_key = os.getenv("POLYGON_API_KEY")
polygon_plan = os.getenv("POLYGON_PLAN")

is_paid_polygon = polygon_plan == "paid"
is_realtime_polygon = polygon_plan == "realtime"

print(is_paid_polygon)
print(is_realtime_polygon)
# Out:
# False
# False

# %%
if is_paid_polygon or is_realtime_polygon:
    market_mcp = {"command": "uvx","args": ["--from", "git+https://github.com/polygon-io/mcp_polygon@master", "mcp_polygon"], "env": {"POLYGON_API_KEY": polygon_api_key}}
else:
    market_mcp = ({"command": "uv", "args": ["run", "market_server.py"]})

trader_mcp_server_params = [
    {"command": "uv", "args": ["run", "accounts_server.py"]},
    {"command": "uv", "args": ["run", "push_server.py"]},
    market_mcp
]

# %% [markdown]
# ### And now for our researcher

# %%
serper_env = {"SERPER_API_KEY": os.getenv("SERPER_API_KEY")}
researcher_mcp_server_params = [
    {"command": "uvx", "args": ["mcp-server-fetch"]},
    {"command": "npx", "args": ["-y", "serper-search-mcp"], "env": serper_env}
]

# %% [markdown]
# ### Now create the MCPServerStdio for each

# %%
researcher_mcp_servers = [MCPServerStdio(params, client_session_timeout_seconds=30) for params in researcher_mcp_server_params]
trader_mcp_servers = [MCPServerStdio(params, client_session_timeout_seconds=30) for params in trader_mcp_server_params]
mcp_servers = trader_mcp_servers + researcher_mcp_servers

# %% [markdown]
# ### Now let's make a Researcher Agent to do market research
#
# And turn it into a tool - remember how this works for OpenAI Agents SDK, and the difference with handoffs?

# %%
async def get_researcher(mcp_servers) -> Agent:
    instructions = f"""You are a financial researcher. You are able to search the web for interesting financial news,
look for possible trading opportunities, and help with research.
Based on the request, you carry out necessary research and respond with your findings.
Take time to make multiple searches to get a comprehensive overview, and then summarize your findings.
If there isn't a specific request, then just respond with investment opportunities based on searching latest news.
The current datetime is {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}
"""
    researcher = Agent(
        name="Researcher",
        instructions=instructions,
        model="gpt-4.1-mini",
        mcp_servers=mcp_servers,
    )
    return researcher

# %%
async def get_researcher_tool(mcp_servers) -> Tool:
    researcher = await get_researcher(mcp_servers)
    return researcher.as_tool(
            tool_name="Researcher",
            tool_description="This tool researches online for news and opportunities, \
                either based on your specific request to look into a certain stock, \
                or generally for notable financial news and opportunities. \
                Describe what kind of research you're looking for."
        )

# %%
research_question = "What's the latest news on Amazon? Research Harder"

for server in researcher_mcp_servers:
    await server.connect()
researcher = await get_researcher(researcher_mcp_servers)
with trace("Researcher"):
    result = await Runner.run(researcher, research_question, max_turns=30)
display(Markdown(result.final_output))
# Out:
# ---------------------------------------------------------------------------
# WouldBlock                                Traceback (most recent call last)
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/anyio/streams/memory.py:111, in MemoryObjectReceiveStream.receive(self)
#     110 try:
# --> 111     return self.receive_nowait()
#     112 except WouldBlock:
#     113     # Add ourselves in the queue
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/anyio/streams/memory.py:106, in MemoryObjectReceiveStream.receive_nowait(self)
#     104     raise EndOfStream
# --> 106 raise WouldBlock
#
# WouldBlock:
#
# During handling of the above exception, another exception occurred:
#
# CancelledError                            Traceback (most recent call last)
# Cell In[10], line 7
#       5 researcher = await get_researcher(researcher_mcp_servers)
#       6 with trace("Researcher"):
# ----> 7     result = await Runner.run(researcher, research_question, max_turns=30)
#       8 display(Markdown(result.final_output))
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/run.py:296, in Runner.run(cls, starting_agent, input, context, max_turns, hooks, run_config, previous_response_id, conversation_id, session)
#     247 """
#     248 Run a workflow starting at the given agent.
#     249
#    (...)    292     type of the output.
#     293 """
#     295 runner = DEFAULT_AGENT_RUNNER
# --> 296 return await runner.run(
#     297     starting_agent,
#     298     input,
#     299     context=context,
#     300     max_turns=max_turns,
#     301     hooks=hooks,
#     302     run_config=run_config,
#     303     previous_response_id=previous_response_id,
#     304     conversation_id=conversation_id,
#     305     session=session,
#     306 )
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/run.py:571, in AgentRunner.run(self, starting_agent, input, **kwargs)
#     548     input_guardrail_results, turn_result = await asyncio.gather(
#     549         self._run_input_guardrails(
#     550             starting_agent,
#    (...)    568         ),
#     569     )
#     570 else:
# --> 571     turn_result = await self._run_single_turn(
#     572         agent=current_agent,
#     573         all_tools=all_tools,
#     574         original_input=original_input,
#     575         generated_items=generated_items,
#     576         hooks=hooks,
#     577         context_wrapper=context_wrapper,
#     578         run_config=run_config,
#     579         should_run_agent_start_hooks=should_run_agent_start_hooks,
#     580         tool_use_tracker=tool_use_tracker,
#     581         previous_response_id=previous_response_id,
#     582         conversation_id=conversation_id,
#     583     )
#     584 should_run_agent_start_hooks = False
#     586 model_responses.append(turn_result.model_response)
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/run.py:1262, in AgentRunner._run_single_turn(cls, agent, all_tools, original_input, generated_items, hooks, context_wrapper, run_config, should_run_agent_start_hooks, tool_use_tracker, previous_response_id, conversation_id)
#    1244 input.extend([generated_item.to_input_item() for generated_item in generated_items])
#    1246 new_response = await cls._get_new_response(
#    1247     agent,
#    1248     system_prompt,
#    (...)   1259     prompt_config,
#    1260 )
# -> 1262 return await cls._get_single_step_result_from_response(
#    1263     agent=agent,
#    1264     original_input=original_input,
#    1265     pre_step_items=generated_items,
#    1266     new_response=new_response,
#    1267     output_schema=output_schema,
#    1268     all_tools=all_tools,
#    1269     handoffs=handoffs,
#    1270     hooks=hooks,
#    1271     context_wrapper=context_wrapper,
#    1272     run_config=run_config,
#    1273     tool_use_tracker=tool_use_tracker,
#    1274 )
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/run.py:1311, in AgentRunner._get_single_step_result_from_response(cls, agent, all_tools, original_input, pre_step_items, new_response, output_schema, handoffs, hooks, context_wrapper, run_config, tool_use_tracker, event_queue)
#    1308     if handoff_items:
#    1309         RunImpl.stream_step_items_to_queue(cast(list[RunItem], handoff_items), event_queue)
# -> 1311 return await RunImpl.execute_tools_and_side_effects(
#    1312     agent=agent,
#    1313     original_input=original_input,
#    1314     pre_step_items=pre_step_items,
#    1315     new_response=new_response,
#    1316     processed_response=processed_response,
#    1317     output_schema=output_schema,
#    1318     hooks=hooks,
#    1319     context_wrapper=context_wrapper,
#    1320     run_config=run_config,
#    1321 )
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/_run_impl.py:274, in RunImpl.execute_tools_and_side_effects(cls, agent, original_input, pre_step_items, new_response, processed_response, output_schema, hooks, context_wrapper, run_config)
#     268 new_step_items.extend(processed_response.new_items)
#     270 # First, lets run the tool calls - function tools and computer actions
#     271 (
#     272     (function_results, tool_input_guardrail_results, tool_output_guardrail_results),
#     273     computer_results,
# --> 274 ) = await asyncio.gather(
#     275     cls.execute_function_tool_calls(
#     276         agent=agent,
#     277         tool_runs=processed_response.functions,
#     278         hooks=hooks,
#     279         context_wrapper=context_wrapper,
#     280         config=run_config,
#     281     ),
#     282     cls.execute_computer_actions(
#     283         agent=agent,
#     284         actions=processed_response.computer_actions,
#     285         hooks=hooks,
#     286         context_wrapper=context_wrapper,
#     287         config=run_config,
#     288     ),
#     289 )
#     290 new_step_items.extend([result.run_item for result in function_results])
#     291 new_step_items.extend(computer_results)
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/_run_impl.py:818, in RunImpl.execute_function_tool_calls(cls, agent, tool_runs, hooks, context_wrapper, config)
#     815     function_tool = tool_run.function_tool
#     816     tasks.append(run_single_tool(function_tool, tool_run.tool_call))
# --> 818 results = await asyncio.gather(*tasks)
#     820 function_tool_results = [
#     821     FunctionToolResult(
#     822         tool=tool_run.function_tool,
#    (...)    830     for tool_run, result in zip(tool_runs, results)
#     831 ]
#     833 return function_tool_results, tool_input_guardrail_results, tool_output_guardrail_results
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/_run_impl.py:769, in RunImpl.execute_function_tool_calls.<locals>.run_single_tool(func_tool, tool_call)
#     766     final_result = rejected_message
#     767 else:
#     768     # 2) Actually run the tool
# --> 769     real_result = await cls._execute_tool_with_hooks(
#     770         func_tool=func_tool,
#     771         tool_context=tool_context,
#     772         agent=agent,
#     773         hooks=hooks,
#     774         tool_call=tool_call,
#     775     )
#     777     # 3) Run output tool guardrails, if any
#     778     final_result = await cls._execute_output_guardrails(
#     779         func_tool=func_tool,
#     780         tool_context=tool_context,
#    (...)    783         tool_output_guardrail_results=tool_output_guardrail_results,
#     784     )
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/_run_impl.py:726, in RunImpl._execute_tool_with_hooks(cls, func_tool, tool_context, agent, hooks, tool_call)
#     705 """Execute the core tool function with before/after hooks.
#     706
#     707 Args:
#    (...)    715     The result from the tool execution.
#     716 """
#     717 await asyncio.gather(
#     718     hooks.on_tool_start(tool_context, agent, func_tool),
#     719     (
#    (...)    723     ),
#     724 )
# --> 726 return await func_tool.on_invoke_tool(tool_context, tool_call.arguments)
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/mcp/util.py:187, in MCPUtil.invoke_mcp_tool(cls, server, tool, context, input_json)
#     184     logger.debug(f"Invoking MCP tool {tool.name} with input {input_json}")
#     186 try:
# --> 187     result = await server.call_tool(tool.name, json_data)
#     188 except Exception as e:
#     189     logger.error(f"Error invoking MCP tool {tool.name}: {e}")
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/mcp/server.py:321, in _MCPServerWithClientSession.call_tool(self, tool_name, arguments)
#     318 session = self.session
#     319 assert session is not None
# --> 321 return await self._run_with_retries(lambda: session.call_tool(tool_name, arguments))
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/mcp/server.py:251, in _MCPServerWithClientSession._run_with_retries(self, func)
#     249 while True:
#     250     try:
# --> 251         return await func()
#     252     except Exception:
#     253         attempts += 1
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/mcp/client/session.py:279, in ClientSession.call_tool(self, name, arguments, read_timeout_seconds, progress_callback)
#     270 async def call_tool(
#     271     self,
#     272     name: str,
#    (...)    275     progress_callback: ProgressFnT | None = None,
#     276 ) -> types.CallToolResult:
#     277     """Send a tools/call request with optional progress callback support."""
# --> 279     result = await self.send_request(
#     280         types.ClientRequest(
#     281             types.CallToolRequest(
#     282                 params=types.CallToolRequestParams(
#     283                     name=name,
#     284                     arguments=arguments,
#     285                 ),
#     286             )
#     287         ),
#     288         types.CallToolResult,
#     289         request_read_timeout_seconds=read_timeout_seconds,
#     290         progress_callback=progress_callback,
#     291     )
#     293     if not result.isError:
#     294         await self._validate_tool_result(name, result)
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/mcp/shared/session.py:272, in BaseSession.send_request(self, request, result_type, request_read_timeout_seconds, metadata, progress_callback)
#     270 try:
#     271     with anyio.fail_after(timeout):
# --> 272         response_or_error = await response_stream_reader.receive()
#     273 except TimeoutError:
#     274     raise McpError(
#     275         ErrorData(
#     276             code=httpx.codes.REQUEST_TIMEOUT,
#    (...)    282         )
#     283     )
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/anyio/streams/memory.py:119, in MemoryObjectReceiveStream.receive(self)
#     116 self._state.waiting_receivers[receive_event] = receiver
#     118 try:
# --> 119     await receive_event.wait()
#     120 finally:
#     121     self._state.waiting_receivers.pop(receive_event, None)
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:1783, in Event.wait(self)
#    1781     await AsyncIOBackend.checkpoint()
#    1782 else:
# -> 1783     await self._event.wait()
#
# File ~/.local/share/uv/python/cpython-3.12.13-macos-aarch64-none/lib/python3.12/asyncio/locks.py:212, in Event.wait(self)
#     210 self._waiters.append(fut)
#     211 try:
# --> 212     await fut
#     213     return True
#     214 finally:
#
# CancelledError:
# Failed to parse JSONRPC message from server
# Traceback (most recent call last):
#   File "/Users/anuppal/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/mcp/client/stdio/__init__.py", line 155, in stdout_reader
#     message = types.JSONRPCMessage.model_validate_json(line)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/anuppal/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/pydantic/main.py", line 746, in model_validate_json
#     return cls.__pydantic_validator__.validate_json(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# pydantic_core._pydantic_core.ValidationError: 1 validation error for JSONRPCMessage
#   Invalid JSON: EOF while parsing a value at line 1 column 0 [type=json_invalid, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.11/v/json_invalid

# %% [markdown]
# ### Look at the trace
#
# https://platform.openai.com/traces

# %%
ed_initial_strategy = "You are a day trader that aggressively buys and sells shares based on news and market conditions."
Account.get("Ed").reset(ed_initial_strategy)

display(Markdown(await read_accounts_resource("Ed")))
display(Markdown(await read_strategy_resource("Ed")))
# Out:
# {"name": "ed", "balance": 10000.0, "strategy": "You are a day trader that aggressively buys and sells shares based on news and market conditions.", "holdings": {}, "transactions": [], "portfolio_value_time_series": [["2026-04-05 17:12:48", 10000.0]], "total_portfolio_value": 10000.0, "total_profit_loss": 0.0}
# You are a day trader that aggressively buys and sells shares based on news and market conditions.

# %% [markdown]
# ### And now - to create our Trader Agent

# %%
agent_name = "Ed"

# Using MCP Servers to read resources
account_details = await read_accounts_resource(agent_name)
strategy = await read_strategy_resource(agent_name)

instructions = f"""
You are a trader that manages a portfolio of shares. Your name is {agent_name} and your account is under your name, {agent_name}.
You have access to tools that allow you to search the internet for company news, check stock prices, and buy and sell shares.
Your investment strategy for your portfolio is:
{strategy}
Your current holdings and balance is:
{account_details}
You have the tools to perform a websearch for relevant news and information.
You have tools to check stock prices.
You have tools to buy and sell shares.
You have tools to save memory of companies, research and thinking so far.
Please make use of these tools to manage your portfolio. Carry out trades as you see fit; do not wait for instructions or ask for confirmation.
"""

prompt = """
Use your tools to make decisions about your portfolio.
Investigate the news and the market, make your decision, make the trades, and respond with a summary of your actions.
"""

# %%
print(instructions)
# Out:
# You are a trader that manages a portfolio of shares. Your name is Ed and your account is under your name, Ed.
# You have access to tools that allow you to search the internet for company news, check stock prices, and buy and sell shares.
# Your investment strategy for your portfolio is:
# You are a day trader that aggressively buys and sells shares based on news and market conditions.
# Your current holdings and balance is:
# {"name": "ed", "balance": 10000.0, "strategy": "You are a day trader that aggressively buys and sells shares based on news and market conditions.", "holdings": {}, "transactions": [], "portfolio_value_time_series": [["2026-04-05 13:02:55", 10000.0], ["2026-04-05 13:03:20", 10000.0]], "total_portfolio_value": 10000.0, "total_profit_loss": 0.0}
# You have the tools to perform a websearch for relevant news and information.
# You have tools to check stock prices.
# You have tools to buy and sell shares.
# You have tools to save memory of companies, research and thinking so far.
# Please make use of these tools to manage your portfolio. Carry out trades as you see fit; do not wait for instructions or ask for confirmation.

# %% [markdown]
# ### And to run our Trader

# %%
for server in mcp_servers:
    await server.connect()

researcher_tool = await get_researcher_tool(researcher_mcp_servers)
trader = Agent(
    name=agent_name,
    instructions=instructions,
    tools=[researcher_tool],
    mcp_servers=trader_mcp_servers,
    model="gpt-4o-mini",
)
with trace(agent_name):
    result = await Runner.run(trader, prompt, max_turns=30)
display(Markdown(result.final_output))
# Out:
# ---------------------------------------------------------------------------
# WouldBlock                                Traceback (most recent call last)
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/anyio/streams/memory.py:111, in MemoryObjectReceiveStream.receive(self)
#     110 try:
# --> 111     return self.receive_nowait()
#     112 except WouldBlock:
#     113     # Add ourselves in the queue
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/anyio/streams/memory.py:106, in MemoryObjectReceiveStream.receive_nowait(self)
#     104     raise EndOfStream
# --> 106 raise WouldBlock
#
# WouldBlock:
#
# During handling of the above exception, another exception occurred:
#
# CancelledError                            Traceback (most recent call last)
# Cell In[14], line 13
#       5 trader = Agent(
#       6     name=agent_name,
#       7     instructions=instructions,
#    (...)     10     model="gpt-4o-mini",
#      11 )
#      12 with trace(agent_name):
# ---> 13     result = await Runner.run(trader, prompt, max_turns=30)
#      14 display(Markdown(result.final_output))
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/run.py:296, in Runner.run(cls, starting_agent, input, context, max_turns, hooks, run_config, previous_response_id, conversation_id, session)
#     247 """
#     248 Run a workflow starting at the given agent.
#     249
#    (...)    292     type of the output.
#     293 """
#     295 runner = DEFAULT_AGENT_RUNNER
# --> 296 return await runner.run(
#     297     starting_agent,
#     298     input,
#     299     context=context,
#     300     max_turns=max_turns,
#     301     hooks=hooks,
#     302     run_config=run_config,
#     303     previous_response_id=previous_response_id,
#     304     conversation_id=conversation_id,
#     305     session=session,
#     306 )
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/run.py:548, in AgentRunner.run(self, starting_agent, input, **kwargs)
#     543 logger.debug(
#     544     f"Running agent {current_agent.name} (turn {current_turn})",
#     545 )
#     547 if current_turn == 1:
# --> 548     input_guardrail_results, turn_result = await asyncio.gather(
#     549         self._run_input_guardrails(
#     550             starting_agent,
#     551             starting_agent.input_guardrails
#     552             + (run_config.input_guardrails or []),
#     553             _copy_str_or_list(prepared_input),
#     554             context_wrapper,
#     555         ),
#     556         self._run_single_turn(
#     557             agent=current_agent,
#     558             all_tools=all_tools,
#     559             original_input=original_input,
#     560             generated_items=generated_items,
#     561             hooks=hooks,
#     562             context_wrapper=context_wrapper,
#     563             run_config=run_config,
#     564             should_run_agent_start_hooks=should_run_agent_start_hooks,
#     565             tool_use_tracker=tool_use_tracker,
#     566             previous_response_id=previous_response_id,
#     567             conversation_id=conversation_id,
#     568         ),
#     569     )
#     570 else:
#     571     turn_result = await self._run_single_turn(
#     572         agent=current_agent,
#     573         all_tools=all_tools,
#    (...)    582         conversation_id=conversation_id,
#     583     )
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/run.py:1262, in AgentRunner._run_single_turn(cls, agent, all_tools, original_input, generated_items, hooks, context_wrapper, run_config, should_run_agent_start_hooks, tool_use_tracker, previous_response_id, conversation_id)
#    1244 input.extend([generated_item.to_input_item() for generated_item in generated_items])
#    1246 new_response = await cls._get_new_response(
#    1247     agent,
#    1248     system_prompt,
#    (...)   1259     prompt_config,
#    1260 )
# -> 1262 return await cls._get_single_step_result_from_response(
#    1263     agent=agent,
#    1264     original_input=original_input,
#    1265     pre_step_items=generated_items,
#    1266     new_response=new_response,
#    1267     output_schema=output_schema,
#    1268     all_tools=all_tools,
#    1269     handoffs=handoffs,
#    1270     hooks=hooks,
#    1271     context_wrapper=context_wrapper,
#    1272     run_config=run_config,
#    1273     tool_use_tracker=tool_use_tracker,
#    1274 )
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/run.py:1311, in AgentRunner._get_single_step_result_from_response(cls, agent, all_tools, original_input, pre_step_items, new_response, output_schema, handoffs, hooks, context_wrapper, run_config, tool_use_tracker, event_queue)
#    1308     if handoff_items:
#    1309         RunImpl.stream_step_items_to_queue(cast(list[RunItem], handoff_items), event_queue)
# -> 1311 return await RunImpl.execute_tools_and_side_effects(
#    1312     agent=agent,
#    1313     original_input=original_input,
#    1314     pre_step_items=pre_step_items,
#    1315     new_response=new_response,
#    1316     processed_response=processed_response,
#    1317     output_schema=output_schema,
#    1318     hooks=hooks,
#    1319     context_wrapper=context_wrapper,
#    1320     run_config=run_config,
#    1321 )
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/_run_impl.py:274, in RunImpl.execute_tools_and_side_effects(cls, agent, original_input, pre_step_items, new_response, processed_response, output_schema, hooks, context_wrapper, run_config)
#     268 new_step_items.extend(processed_response.new_items)
#     270 # First, lets run the tool calls - function tools and computer actions
#     271 (
#     272     (function_results, tool_input_guardrail_results, tool_output_guardrail_results),
#     273     computer_results,
# --> 274 ) = await asyncio.gather(
#     275     cls.execute_function_tool_calls(
#     276         agent=agent,
#     277         tool_runs=processed_response.functions,
#     278         hooks=hooks,
#     279         context_wrapper=context_wrapper,
#     280         config=run_config,
#     281     ),
#     282     cls.execute_computer_actions(
#     283         agent=agent,
#     284         actions=processed_response.computer_actions,
#     285         hooks=hooks,
#     286         context_wrapper=context_wrapper,
#     287         config=run_config,
#     288     ),
#     289 )
#     290 new_step_items.extend([result.run_item for result in function_results])
#     291 new_step_items.extend(computer_results)
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/_run_impl.py:818, in RunImpl.execute_function_tool_calls(cls, agent, tool_runs, hooks, context_wrapper, config)
#     815     function_tool = tool_run.function_tool
#     816     tasks.append(run_single_tool(function_tool, tool_run.tool_call))
# --> 818 results = await asyncio.gather(*tasks)
#     820 function_tool_results = [
#     821     FunctionToolResult(
#     822         tool=tool_run.function_tool,
#    (...)    830     for tool_run, result in zip(tool_runs, results)
#     831 ]
#     833 return function_tool_results, tool_input_guardrail_results, tool_output_guardrail_results
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/_run_impl.py:769, in RunImpl.execute_function_tool_calls.<locals>.run_single_tool(func_tool, tool_call)
#     766     final_result = rejected_message
#     767 else:
#     768     # 2) Actually run the tool
# --> 769     real_result = await cls._execute_tool_with_hooks(
#     770         func_tool=func_tool,
#     771         tool_context=tool_context,
#     772         agent=agent,
#     773         hooks=hooks,
#     774         tool_call=tool_call,
#     775     )
#     777     # 3) Run output tool guardrails, if any
#     778     final_result = await cls._execute_output_guardrails(
#     779         func_tool=func_tool,
#     780         tool_context=tool_context,
#    (...)    783         tool_output_guardrail_results=tool_output_guardrail_results,
#     784     )
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/_run_impl.py:726, in RunImpl._execute_tool_with_hooks(cls, func_tool, tool_context, agent, hooks, tool_call)
#     705 """Execute the core tool function with before/after hooks.
#     706
#     707 Args:
#    (...)    715     The result from the tool execution.
#     716 """
#     717 await asyncio.gather(
#     718     hooks.on_tool_start(tool_context, agent, func_tool),
#     719     (
#    (...)    723     ),
#     724 )
# --> 726 return await func_tool.on_invoke_tool(tool_context, tool_call.arguments)
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/tool.py:449, in function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool(ctx, input)
#     447 async def _on_invoke_tool(ctx: ToolContext[Any], input: str) -> Any:
#     448     try:
# --> 449         return await _on_invoke_tool_impl(ctx, input)
#     450     except Exception as e:
#     451         if failure_error_function is None:
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/tool.py:431, in function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool_impl(ctx, input)
#     429 if inspect.iscoroutinefunction(the_func):
#     430     if schema.takes_context:
# --> 431         result = await the_func(ctx, *args, **kwargs_dict)
#     432     else:
#     433         result = await the_func(*args, **kwargs_dict)
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/agent.py:425, in Agent.as_tool.<locals>.run_agent(context, input)
#     421 from .run import DEFAULT_MAX_TURNS, Runner
#     423 resolved_max_turns = max_turns if max_turns is not None else DEFAULT_MAX_TURNS
# --> 425 output = await Runner.run(
#     426     starting_agent=self,
#     427     input=input,
#     428     context=context.context,
#     429     run_config=run_config,
#     430     max_turns=resolved_max_turns,
#     431     hooks=hooks,
#     432     previous_response_id=previous_response_id,
#     433     conversation_id=conversation_id,
#     434     session=session,
#     435 )
#     436 if custom_output_extractor:
#     437     return await custom_output_extractor(output)
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/run.py:296, in Runner.run(cls, starting_agent, input, context, max_turns, hooks, run_config, previous_response_id, conversation_id, session)
#     247 """
#     248 Run a workflow starting at the given agent.
#     249
#    (...)    292     type of the output.
#     293 """
#     295 runner = DEFAULT_AGENT_RUNNER
# --> 296 return await runner.run(
#     297     starting_agent,
#     298     input,
#     299     context=context,
#     300     max_turns=max_turns,
#     301     hooks=hooks,
#     302     run_config=run_config,
#     303     previous_response_id=previous_response_id,
#     304     conversation_id=conversation_id,
#     305     session=session,
#     306 )
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/run.py:548, in AgentRunner.run(self, starting_agent, input, **kwargs)
#     543 logger.debug(
#     544     f"Running agent {current_agent.name} (turn {current_turn})",
#     545 )
#     547 if current_turn == 1:
# --> 548     input_guardrail_results, turn_result = await asyncio.gather(
#     549         self._run_input_guardrails(
#     550             starting_agent,
#     551             starting_agent.input_guardrails
#     552             + (run_config.input_guardrails or []),
#     553             _copy_str_or_list(prepared_input),
#     554             context_wrapper,
#     555         ),
#     556         self._run_single_turn(
#     557             agent=current_agent,
#     558             all_tools=all_tools,
#     559             original_input=original_input,
#     560             generated_items=generated_items,
#     561             hooks=hooks,
#     562             context_wrapper=context_wrapper,
#     563             run_config=run_config,
#     564             should_run_agent_start_hooks=should_run_agent_start_hooks,
#     565             tool_use_tracker=tool_use_tracker,
#     566             previous_response_id=previous_response_id,
#     567             conversation_id=conversation_id,
#     568         ),
#     569     )
#     570 else:
#     571     turn_result = await self._run_single_turn(
#     572         agent=current_agent,
#     573         all_tools=all_tools,
#    (...)    582         conversation_id=conversation_id,
#     583     )
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/run.py:1262, in AgentRunner._run_single_turn(cls, agent, all_tools, original_input, generated_items, hooks, context_wrapper, run_config, should_run_agent_start_hooks, tool_use_tracker, previous_response_id, conversation_id)
#    1244 input.extend([generated_item.to_input_item() for generated_item in generated_items])
#    1246 new_response = await cls._get_new_response(
#    1247     agent,
#    1248     system_prompt,
#    (...)   1259     prompt_config,
#    1260 )
# -> 1262 return await cls._get_single_step_result_from_response(
#    1263     agent=agent,
#    1264     original_input=original_input,
#    1265     pre_step_items=generated_items,
#    1266     new_response=new_response,
#    1267     output_schema=output_schema,
#    1268     all_tools=all_tools,
#    1269     handoffs=handoffs,
#    1270     hooks=hooks,
#    1271     context_wrapper=context_wrapper,
#    1272     run_config=run_config,
#    1273     tool_use_tracker=tool_use_tracker,
#    1274 )
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/run.py:1311, in AgentRunner._get_single_step_result_from_response(cls, agent, all_tools, original_input, pre_step_items, new_response, output_schema, handoffs, hooks, context_wrapper, run_config, tool_use_tracker, event_queue)
#    1308     if handoff_items:
#    1309         RunImpl.stream_step_items_to_queue(cast(list[RunItem], handoff_items), event_queue)
# -> 1311 return await RunImpl.execute_tools_and_side_effects(
#    1312     agent=agent,
#    1313     original_input=original_input,
#    1314     pre_step_items=pre_step_items,
#    1315     new_response=new_response,
#    1316     processed_response=processed_response,
#    1317     output_schema=output_schema,
#    1318     hooks=hooks,
#    1319     context_wrapper=context_wrapper,
#    1320     run_config=run_config,
#    1321 )
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/_run_impl.py:274, in RunImpl.execute_tools_and_side_effects(cls, agent, original_input, pre_step_items, new_response, processed_response, output_schema, hooks, context_wrapper, run_config)
#     268 new_step_items.extend(processed_response.new_items)
#     270 # First, lets run the tool calls - function tools and computer actions
#     271 (
#     272     (function_results, tool_input_guardrail_results, tool_output_guardrail_results),
#     273     computer_results,
# --> 274 ) = await asyncio.gather(
#     275     cls.execute_function_tool_calls(
#     276         agent=agent,
#     277         tool_runs=processed_response.functions,
#     278         hooks=hooks,
#     279         context_wrapper=context_wrapper,
#     280         config=run_config,
#     281     ),
#     282     cls.execute_computer_actions(
#     283         agent=agent,
#     284         actions=processed_response.computer_actions,
#     285         hooks=hooks,
#     286         context_wrapper=context_wrapper,
#     287         config=run_config,
#     288     ),
#     289 )
#     290 new_step_items.extend([result.run_item for result in function_results])
#     291 new_step_items.extend(computer_results)
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/_run_impl.py:818, in RunImpl.execute_function_tool_calls(cls, agent, tool_runs, hooks, context_wrapper, config)
#     815     function_tool = tool_run.function_tool
#     816     tasks.append(run_single_tool(function_tool, tool_run.tool_call))
# --> 818 results = await asyncio.gather(*tasks)
#     820 function_tool_results = [
#     821     FunctionToolResult(
#     822         tool=tool_run.function_tool,
#    (...)    830     for tool_run, result in zip(tool_runs, results)
#     831 ]
#     833 return function_tool_results, tool_input_guardrail_results, tool_output_guardrail_results
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/_run_impl.py:769, in RunImpl.execute_function_tool_calls.<locals>.run_single_tool(func_tool, tool_call)
#     766     final_result = rejected_message
#     767 else:
#     768     # 2) Actually run the tool
# --> 769     real_result = await cls._execute_tool_with_hooks(
#     770         func_tool=func_tool,
#     771         tool_context=tool_context,
#     772         agent=agent,
#     773         hooks=hooks,
#     774         tool_call=tool_call,
#     775     )
#     777     # 3) Run output tool guardrails, if any
#     778     final_result = await cls._execute_output_guardrails(
#     779         func_tool=func_tool,
#     780         tool_context=tool_context,
#    (...)    783         tool_output_guardrail_results=tool_output_guardrail_results,
#     784     )
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/_run_impl.py:726, in RunImpl._execute_tool_with_hooks(cls, func_tool, tool_context, agent, hooks, tool_call)
#     705 """Execute the core tool function with before/after hooks.
#     706
#     707 Args:
#    (...)    715     The result from the tool execution.
#     716 """
#     717 await asyncio.gather(
#     718     hooks.on_tool_start(tool_context, agent, func_tool),
#     719     (
#    (...)    723     ),
#     724 )
# --> 726 return await func_tool.on_invoke_tool(tool_context, tool_call.arguments)
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/mcp/util.py:187, in MCPUtil.invoke_mcp_tool(cls, server, tool, context, input_json)
#     184     logger.debug(f"Invoking MCP tool {tool.name} with input {input_json}")
#     186 try:
# --> 187     result = await server.call_tool(tool.name, json_data)
#     188 except Exception as e:
#     189     logger.error(f"Error invoking MCP tool {tool.name}: {e}")
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/mcp/server.py:321, in _MCPServerWithClientSession.call_tool(self, tool_name, arguments)
#     318 session = self.session
#     319 assert session is not None
# --> 321 return await self._run_with_retries(lambda: session.call_tool(tool_name, arguments))
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/mcp/server.py:251, in _MCPServerWithClientSession._run_with_retries(self, func)
#     249 while True:
#     250     try:
# --> 251         return await func()
#     252     except Exception:
#     253         attempts += 1
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/mcp/client/session.py:279, in ClientSession.call_tool(self, name, arguments, read_timeout_seconds, progress_callback)
#     270 async def call_tool(
#     271     self,
#     272     name: str,
#    (...)    275     progress_callback: ProgressFnT | None = None,
#     276 ) -> types.CallToolResult:
#     277     """Send a tools/call request with optional progress callback support."""
# --> 279     result = await self.send_request(
#     280         types.ClientRequest(
#     281             types.CallToolRequest(
#     282                 params=types.CallToolRequestParams(
#     283                     name=name,
#     284                     arguments=arguments,
#     285                 ),
#     286             )
#     287         ),
#     288         types.CallToolResult,
#     289         request_read_timeout_seconds=read_timeout_seconds,
#     290         progress_callback=progress_callback,
#     291     )
#     293     if not result.isError:
#     294         await self._validate_tool_result(name, result)
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/mcp/shared/session.py:272, in BaseSession.send_request(self, request, result_type, request_read_timeout_seconds, metadata, progress_callback)
#     270 try:
#     271     with anyio.fail_after(timeout):
# --> 272         response_or_error = await response_stream_reader.receive()
#     273 except TimeoutError:
#     274     raise McpError(
#     275         ErrorData(
#     276             code=httpx.codes.REQUEST_TIMEOUT,
#    (...)    282         )
#     283     )
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/anyio/streams/memory.py:119, in MemoryObjectReceiveStream.receive(self)
#     116 self._state.waiting_receivers[receive_event] = receiver
#     118 try:
# --> 119     await receive_event.wait()
#     120 finally:
#     121     self._state.waiting_receivers.pop(receive_event, None)
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:1783, in Event.wait(self)
#    1781     await AsyncIOBackend.checkpoint()
#    1782 else:
# -> 1783     await self._event.wait()
#
# File ~/.local/share/uv/python/cpython-3.12.13-macos-aarch64-none/lib/python3.12/asyncio/locks.py:212, in Event.wait(self)
#     210 self._waiters.append(fut)
#     211 try:
# --> 212     await fut
#     213     return True
#     214 finally:
#
# CancelledError:

# %% [markdown]
# ### Then go and look at the trace
#
# http://platform.openai.com/traces

# %%
# And let's look at the results of the trading

await read_accounts_resource(agent_name)
# Out:
# '{"name": "ed", "balance": 10000.0, "strategy": "You are a day trader that aggressively buys and sells shares based on news and market conditions.", "holdings": {}, "transactions": [], "portfolio_value_time_series": [["2026-04-05 17:12:48", 10000.0], ["2026-04-05 17:12:51", 10000.0], ["2026-04-05 17:13:07", 10000.0]], "total_portfolio_value": 10000.0, "total_profit_loss": 0.0}'

# %% [markdown]
# ### Now it's time to review the Python module made from this:
#
# `mcp_params.py` is where the MCP servers are specified. You'll notice I've brought in some familiar friends: memory and push notifications!
#
# `templates.py` is where the instructions and messages are set up (i.e. the System prompts and User prompts)
#
# `traders.py` brings it all together.
#
# You'll notice I've done something a bit fancy with code like this:
#
# ```
# async with AsyncExitStack() as stack:
#     mcp_servers = [await stack.enter_async_context(MCPServerStdio(params)) for params in mcp_server_params]
# ```
#
# This is just a tidy way to combine our "with" statements (known as context managers) so that we don't need to do something ugly like this:
#
# ```
# async with MCPServerStdio(params=params1) as mcp_server1:
#     async with MCPServerStdio(params=params2) as mcp_server2:
#         async with MCPServerStdio(params=params3) as mcp_server3:
#             mcp_servers = [mcp_server1, mcp_server2, mcp_server3]
# ```
#
# But it's equivalent.

# %%
from traders import Trader

# %%
trader = Trader("Ed")
await trader.get_account_report()
await trader.run_with_mcp_servers()
# Out:
# Error initializing MCP server: Connection closed
# ---------------------------------------------------------------------------
# McpError                                  Traceback (most recent call last)
# Cell In[26], line 3
#       1 trader = Trader("Ed")
#       2 await trader.get_account_report()
# ----> 3 await trader.run_with_mcp_servers()
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/6_mcp/traders.py:112, in Trader.run_with_mcp_servers(self)
#     104 async with AsyncExitStack() as stack:
#     105     trader_mcp_servers = [
#     106         await stack.enter_async_context(
#     107             MCPServerStdio(params, client_session_timeout_seconds=120)
#     108         )
#     109         for params in trader_mcp_server_params
#     110     ]
#     111     researcher_mcp_servers = [
# --> 112         await stack.enter_async_context(
#     113             MCPServerStdio(params, client_session_timeout_seconds=120)
#     114         )
#     115         for params in researcher_mcp_server_params(self.name)
#     116     ]
#     117     await self.run_agent(trader_mcp_servers, researcher_mcp_servers)
#
# File ~/.local/share/uv/python/cpython-3.12.13-macos-aarch64-none/lib/python3.12/contextlib.py:659, in AsyncExitStack.enter_async_context(self, cm)
#     655 except AttributeError:
#     656     raise TypeError(f"'{cls.__module__}.{cls.__qualname__}' object does "
#     657                     f"not support the asynchronous context manager protocol"
#     658                    ) from None
# --> 659 result = await _enter(cm)
#     660 self._push_async_cm_exit(cm, _exit)
#     661 return result
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/mcp/server.py:237, in _MCPServerWithClientSession.__aenter__(self)
#     236 async def __aenter__(self):
# --> 237     await self.connect()
#     238     return self
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/mcp/server.py:277, in _MCPServerWithClientSession.connect(self)
#     266 read, write, *_ = transport
#     268 session = await self.exit_stack.enter_async_context(
#     269     ClientSession(
#     270         read,
#    (...)    275     )
#     276 )
# --> 277 server_result = await session.initialize()
#     278 self.server_initialize_result = server_result
#     279 self.session = session
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/mcp/client/session.py:151, in ClientSession.initialize(self)
#     139 elicitation = (
#     140     types.ElicitationCapability() if self._elicitation_callback is not _default_elicitation_callback else None
#     141 )
#     142 roots = (
#     143     # TODO: Should this be based on whether we
#     144     # _will_ send notifications, or only whether
#    (...)    148     else None
#     149 )
# --> 151 result = await self.send_request(
#     152     types.ClientRequest(
#     153         types.InitializeRequest(
#     154             params=types.InitializeRequestParams(
#     155                 protocolVersion=types.LATEST_PROTOCOL_VERSION,
#     156                 capabilities=types.ClientCapabilities(
#     157                     sampling=sampling,
#     158                     elicitation=elicitation,
#     159                     experimental=None,
#     160                     roots=roots,
#     161                 ),
#     162                 clientInfo=self._client_info,
#     163             ),
#     164         )
#     165     ),
#     166     types.InitializeResult,
#     167 )
#     169 if result.protocolVersion not in SUPPORTED_PROTOCOL_VERSIONS:
#     170     raise RuntimeError(f"Unsupported protocol version from the server: {result.protocolVersion}")
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/mcp/shared/session.py:286, in BaseSession.send_request(self, request, result_type, request_read_timeout_seconds, metadata, progress_callback)
#     274     raise McpError(
#     275         ErrorData(
#     276             code=httpx.codes.REQUEST_TIMEOUT,
#    (...)    282         )
#     283     )
#     285 if isinstance(response_or_error, JSONRPCError):
# --> 286     raise McpError(response_or_error.error)
#     287 else:
#     288     return result_type.model_validate(response_or_error.result)
#
# McpError: Connection closed

# %%
await trader.run()
# Out:
# Error initializing MCP server: Connection closed
# Error running trader Ed: Connection closed

# %%
await read_accounts_resource("Ed")
# Out:
# '{"name": "ed", "balance": 757.0309600000007, "strategy": "You are a day trader that aggressively buys and sells shares based on news and market conditions.", "holdings": {"TSLA": 25, "AMZN": 1}, "transactions": [{"symbol": "TSLA", "quantity": 20, "price": 361.31118, "timestamp": "2026-04-05 13:04:25", "rationale": "Stable pricing with potential for short-term gains."}, {"symbol": "TSLA", "quantity": 5, "price": 361.31118, "timestamp": "2026-04-05 13:04:37", "rationale": "Optimizing purchases within available cash."}, {"symbol": "AMZN", "quantity": 1, "price": 210.18954000000002, "timestamp": "2026-04-05 13:04:46", "rationale": "Purchasing 1 share of Amazon within available cash."}], "portfolio_value_time_series": [["2026-04-05 13:02:55", 10000.0], ["2026-04-05 13:03:20", 10000.0], ["2026-04-05 13:04:25", 9985.5764], ["2026-04-05 13:04:37", 9981.970500000001], ["2026-04-05 13:04:46", 9981.55096], ["2026-04-05 13:08:12", 9981.55096], ["2026-04-05 13:08:58", 9981.55096], ["2026-04-05 16:59:31", 9981.55096], ["2026-04-05 16:59:38", 9981.55096]], "total_portfolio_value": 9981.55096, "total_profit_loss": -18.449040000000196}'

# %% [markdown]
# ### Now look at the trace
#
# https://platform.openai.com/traces
#
# ### How many tools did we use in total?

# %%
from mcp_params import trader_mcp_server_params, researcher_mcp_server_params

all_params = trader_mcp_server_params + researcher_mcp_server_params("ed")

count = 0
for each_params in all_params:
    async with MCPServerStdio(params=each_params, client_session_timeout_seconds=60) as server:
        mcp_tools = await server.list_tools()
        count += len(mcp_tools)
print(f"We have {len(all_params)} MCP servers, and {count} tools")
# Out:
# Error initializing MCP server: Connection closed
# ---------------------------------------------------------------------------
# McpError                                  Traceback (most recent call last)
# Cell In[25], line 7
#       5 count = 0
#       6 for each_params in all_params:
# ----> 7     async with MCPServerStdio(params=each_params, client_session_timeout_seconds=60) as server:
#       8         mcp_tools = await server.list_tools()
#       9         count += len(mcp_tools)
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/mcp/server.py:237, in _MCPServerWithClientSession.__aenter__(self)
#     236 async def __aenter__(self):
# --> 237     await self.connect()
#     238     return self
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/agents/mcp/server.py:277, in _MCPServerWithClientSession.connect(self)
#     266 read, write, *_ = transport
#     268 session = await self.exit_stack.enter_async_context(
#     269     ClientSession(
#     270         read,
#    (...)    275     )
#     276 )
# --> 277 server_result = await session.initialize()
#     278 self.server_initialize_result = server_result
#     279 self.session = session
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/mcp/client/session.py:151, in ClientSession.initialize(self)
#     139 elicitation = (
#     140     types.ElicitationCapability() if self._elicitation_callback is not _default_elicitation_callback else None
#     141 )
#     142 roots = (
#     143     # TODO: Should this be based on whether we
#     144     # _will_ send notifications, or only whether
#    (...)    148     else None
#     149 )
# --> 151 result = await self.send_request(
#     152     types.ClientRequest(
#     153         types.InitializeRequest(
#     154             params=types.InitializeRequestParams(
#     155                 protocolVersion=types.LATEST_PROTOCOL_VERSION,
#     156                 capabilities=types.ClientCapabilities(
#     157                     sampling=sampling,
#     158                     elicitation=elicitation,
#     159                     experimental=None,
#     160                     roots=roots,
#     161                 ),
#     162                 clientInfo=self._client_info,
#     163             ),
#     164         )
#     165     ),
#     166     types.InitializeResult,
#     167 )
#     169 if result.protocolVersion not in SUPPORTED_PROTOCOL_VERSIONS:
#     170     raise RuntimeError(f"Unsupported protocol version from the server: {result.protocolVersion}")
#
# File ~/Desktop/Desktop-content/mlproject/AI-Agents/.venv/lib/python3.12/site-packages/mcp/shared/session.py:286, in BaseSession.send_request(self, request, result_type, request_read_timeout_seconds, metadata, progress_callback)
#     274     raise McpError(
#     275         ErrorData(
#     276             code=httpx.codes.REQUEST_TIMEOUT,
#    (...)    282         )
#     283     )
#     285 if isinstance(response_or_error, JSONRPCError):
# --> 286     raise McpError(response_or_error.error)
#     287 else:
#     288     return result_type.model_validate(response_or_error.result)
#
# McpError: Connection closed
