# %% [markdown]
# ## Week 2 Day 1
#
# And now! Our first look at OpenAI Agents SDK
#
# You won't believe how lightweight this is..

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">The OpenAI Agents SDK Docs</h2>
#             <span style="color:#00bfff;">The documentation on OpenAI Agents SDK is really clear and simple: <a href="https://openai.github.io/openai-agents-python/">https://openai.github.io/openai-agents-python/</a> and it's well worth a look.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# The imports

from dotenv import load_dotenv
from agents import Agent, Runner,Trace

# %%
# The usual starting point

load_dotenv(override=True)
# Out:
# True

# %%
# Make an agent with name, instructions, model

agent = Agent(name="LLMtest", instructions="Tell me what is hot right now in the field of AI engineering", model="gpt-4.1")

# %%
# Run the joke with Runner.run(agent, prompt) then print final_output

with trace("News Report"):
    result = await Runner.run(agent, "Tell me what is hot right now in the field of AI engineering")
    print(result.final_output)
# Out:
# Absolutely! As of mid-2024, AI engineering is a dynamic field with some hot trends and developments making waves. Here’s what’s top of mind right now:
#
# ### 1. **Multimodal AI Models**
# - **What:** AI systems like OpenAI’s GPT-4o, Google Gemini, and Meta’s Llama 3 can process and generate text, images, audio, and even video.
# - **Why it’s hot:** These models can power virtual assistants with richer interactions (e.g., analyzing photos and answering questions about them), and they’re being integrated into search, health diagnostics, accessibility tools, and more.
#
# ### 2. **AI Model Efficiency & Edge AI**
# - **What:** Focus on making models smaller, faster, and more efficient for real-world deployment—especially on devices (phones, sensors, robots) without cloud support.
# - **Why it’s hot:** There’s big demand for smart devices and real-time AI processing, plus interest in privacy and data sovereignty.
#
# ### 3. **Agentic and Autonomous AI**
# ...

# %% [markdown]
# ## Now go and look at the trace
#
# https://platform.openai.com/traces
