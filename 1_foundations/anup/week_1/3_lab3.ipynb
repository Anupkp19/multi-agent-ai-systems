# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# anupkumarpal1199@gmail.com
# www.linkedin.com/in/anupkumarpal
# (LinkedIn)
# Top Skills
# Python
# Kafka Streams
# Amazon EKS
# Certifications
# M103: Basic Cluster Administration
# AI Engineering Essentials:
# Navigating the Tech Revolution
# M112: Diagnostic Thinking
# Algorithmic Toolbox
# Anup Pal
# Software Engineer @Bridgestone | Ex-Sprinklr | Java, Spring Boot,
# Microservices, Kafka, Redis | Designing Scalable, High-Performance
# Distributed Systems
# Barjora, West Bengal, India
# Summary
# I’m a backend engineer specializing in distributed systems and
# cloud-native architectures, with a strong focus on resilience,
# performance, and scalability. I design event-driven microservices
# that power high-throughput production systems delivering millions of
# events per month, significant latency reductions and reliable zero-
# downtime operations.
# I bring strong hands-on experience designing systems optimized
# for high concurrency, reliability, and observability, and I’m
# comfortable owning features end-to-end—from system design and
# implementation to deployment, monitoring, and production support in
# live environments.
# ️ Technical Skills
# Languages: Java, Python
# Backend Frameworks: Spring Boot, Hibernate, Spring Data JPA,
# Flask, FastAPI
# Architecture: Microservices, Event-Driven Systems, REST, Pub/Sub
# Messaging & Caching: Kafka, Redis
# Cloud & Infrastructure: AWS (MSK, SQS, SNS, EC2, IAM, VPC),
# Docker, Kubernetes, Serverless
# Databases: PostgreSQL, MySQL, MongoDB, Redis
# CI/CD & Observability: Jenkins, Azure Pipelines, Prometheus,
# Grafana, PagerDuty
# Tools: Git/GitHub, Gradle, Maven, IntelliJ IDEA, Postman, Dapr
# Let’s Connect
# I’m passionate about leveraging my backend engineering expertise
# to build scalable, high-impact systems that drive real business value.
# I’m open to backend, distributed systems, and platform engineering
# roles where I can solve complex technical challenges and contribute
# to large-scale systems.
#   Page 1 of 4
# Reach out via LinkedIn or email: anupkumarpal1199@gmail.com
# Experience
# Bridgestone Americas
# Software Engineer
# December 2024 - Present (1 year 4 months)
# BDIPlus
# Full-stack Developer
# May 2024 - November 2024 (7 months)
# Bengaluru, Karnataka, India
# - Modernized data management architecture by migrating from Redis to
# MySQL, significantly improving system stability and reducing downtime to
# fewer than two incidents per month.
# - Led end-to-end integration of Cashfree and Stripe payment gateways across
# India, the US, and the UAE, streamlining transaction workflows and delivering
# 30% higher customer satisfaction through faster, more reliable payments.
# - Improved API performance, reliability, and efficiency by applying profiling,
# caching, and load-balancing strategies, achieving 40% faster response times,
# 35% higher reliability, and 30% overall efficiency gains.
# - Designed and implemented a centralized logging and observability
# framework using Spring AOP across microservices, enabling request/response
# tracing, execution time monitoring, and exception handling, significantly
# improving production debuggability and reducing issue resolution time.
# Technologies Used:
# Backend & Frameworks: Java, Python, Flask, FastAPI, Spring Framework
# (Spring AOP)
# Databases & Caching: MySQL, Redis
# Payments & Integrations: Cashfree, Stripe
# Programming Languages: Java, Python
# Sprinklr
# 2 years
# Software Engineer
# July 2022 - March 2024 (1 year 9 months)
# Bengaluru, Karnataka, India
#   Page 2 of 4
# - Developed a modular and scalable Restful API using Java, Spring Boot, and
# Microservices architecture, ensuring seamless integration, maintainability, and
# performance optimization.
# - Collaborated on enhancing system security by implementing JWT
# authentication and authorization, ensuring secure access to resources.
# - Implemented pagination and sorting functionalities within API endpoints,
# enhancing efficiency and user experience by 67%.
# - Contributed to the design and development of a microservices architecture,
# enabling easy deployment and maintenance.
# - Utilized Hibernate with Spring Data JPA to streamline database interactions
# and optimize data persistence.
# - Integrated Prometheus and Grafana for Kubernetes monitoring, enhancing
# visibility into system performance. Linked monitoring with PagerDuty
# for proactive alerts, resulting in a 100% decrease in outage likelihood in
# production environments.
# - Implemented an alert system for identifying and terminating unused AWS
# EC2 instances inactive for over 2 weeks, leading to a 30% cost reduction
# through optimized resource allocation and proactive cost management.
# - Leveraged AWS services such as EC2, S3, and RDS for cloud infrastructure,
# ensuring reliable deployment and scalability of applications.
# Technologies Used:
# Backend & Frameworks: Java, Spring Boot, Microservices Architecture
# Databases & Messaging: MongoDB, Apache Kafka
# DevOps & CI/CD: Jenkins, Kubernetes, Ansible, CI/CD Pipelines
# Monitoring & Observability: Prometheus, Grafana, Sensu, InfluxDB, PagerDuty
# Cloud Platforms:
# AWS: EC2, S3, RDS, EKS
# GCP: GKE, GCE
# Programming Languages: Java, Python
# Software Engineer Intern
# April 2022 - July 2022 (4 months)
# Bengaluru, Karnataka, India
# - Designed and implemented CI/CD pipelines on Jenkins for multiple
# environments, enabling automated build, test, and deployment processes.
# Configured email notifications upon pipeline completion for timely updates.
# - Implemented Rest Controller within Spring framework to develop highly
# efficient RESTful Web services for communication.Used Postman to test the
# RESTful API for HTTP requests such as GET, POST, and PUT.
#   Page 3 of 4
# - Ensured robust security measures through expert implementation of
# authentication and authorization mechanisms like OAuth 2.0 and JSON Web
# Tokens (JWT), contributing to enhanced data protection and user privacy.
# - Used Rest Controller in Spring framework to create RESTful Web services
# and JSON objects for communication.
# Technologies Used:
# Backend & Frameworks: Java, Spring Boot, Spring MVC, Spring Security
# Security: OAuth 2.0, JSON Web Tokens (JWT)
# DevOps & CI/CD: Jenkins, Kubernetes, Ansible
# Cloud Platform: Google Cloud Platform (GCP)
# Databases: MongoDB
# Programming Languages: Java, Python
# kaleitics.ai
# Software Developer
# November 2021 - June 2022 (8 months)
# India
# - Worked on developing a prototype of MedRAM software.
# - Worked on developing the database management for MedRAM software.
# - Worked on designing a prototype of circuit for remote monitoring of MedRAM
# software.
# Technologies Used:
# Front-end Development: ReactJS
# Back-end Development: Python, Flask
# Databases: MYSQL
# Education
# B. M. S. College of Engineering
# Bachelor's degree, Biomedical/Medical Engineering · (August 2018 - July
# 2022)
#   Page 4 of 4

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Anup kumar pal"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Anup kumar pal. You are answering questions on Anup kumar pal's website, particularly questions related to Anup kumar pal's career, background, skills and experience. Your responsibility is to represent Anup kumar pal for interactions on the website as faithfully as possible. You are given a summary of Anup kumar pal's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nHi, I am Anup Pal.\n\nI am a software engineer and a tech enthusiast with a strong interest in\nartificial intelligence and modern technologies. I enjoy learning about\nnew tools and platforms and experimenting with them in real-world\nscenarios.\n\nIn my work, I use technologies like Kubernetes for deployment and SQL\nfor storing and managing data. I also frequently work with Java,\nespecially Java streams, filtering operations, counting elements, and\nsolving data structure related problems.\n\nI like exploring AI APIs and developer platforms such as OpenAI, Groq,\nand Gemini. I often experiment with both Python and Java to understand\nhow different systems and APIs work.\n\nMy approach to problem solving is practical and implementation focused.\nI prefer clear and simple solutions that can be directly applied in real\nsystems and backend services.\n\nOutside of core development topics, I also explore areas related to\nhealth, nutrition, and occasional travel around Bangalore.\n\nOne notable experience was during an interview where I proposed a system\ndesign for storing service logs that automatically delete after 12\nhours. The interviewers appreciated the approach and solution.\n\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\nanupkumarpal1199@gmail.com\nwww.linkedin.com/in/anupkumarpal\n(LinkedIn)\nTop Skills\nPython\nKafka Streams\nAmazon EKS\nCertifications\nM103: Basic Cluster Administration\nAI Engineering Essentials:\nNavigating the Tech Revolution\nM112: Diagnostic Thinking\nAlgorithmic Toolbox\nAnup Pal\nSoftware Engineer @Bridgestone | Ex-Sprinklr | Java, Spring Boot,\nMicroservices, Kafka, Redis | Designing Scalable, High-Performance\nDistributed Systems\nBarjora, West Bengal, India\nSummary\nI’m a backend engineer specializing in distributed systems and\ncloud-native architectures, with a strong focus on resilience,\nperformance, and scalability. I design event-driven microservices\nthat power high-throughput production systems delivering millions of\nevents per month, significant latency reductions and reliable zero-\ndowntime operations.\nI bring strong hands-on experience designing systems optimized\nfor high concurrency, reliability, and observability, and I’m\ncomfortable owning features end-to-end—from system design and\nimplementation to deployment, monitoring, and production support in\nlive environments.\n️ Technical Skills\nLanguages: Java, Python\nBackend Frameworks: Spring Boot, Hibernate, Spring Data JPA,\nFlask, FastAPI\nArchitecture: Microservices, Event-Driven Systems, REST, Pub/Sub\nMessaging & Caching: Kafka, Redis\nCloud & Infrastructure: AWS (MSK, SQS, SNS, EC2, IAM, VPC),\nDocker, Kubernetes, Serverless\nDatabases: PostgreSQL, MySQL, MongoDB, Redis\nCI/CD & Observability: Jenkins, Azure Pipelines, Prometheus,\nGrafana, PagerDuty\nTools: Git/GitHub, Gradle, Maven, IntelliJ IDEA, Postman, Dapr\nLet’s Connect\nI’m passionate about leveraging my backend engineering expertise\nto build scalable, high-impact systems that drive real business value.\nI’m open to backend, distributed systems, and platform engineering\nroles where I can solve complex technical challenges and contribute\nto large-scale systems.\n\xa0 Page 1 of 4\xa0 \xa0\nReach out via LinkedIn or email: anupkumarpal1199@gmail.com\nExperience\nBridgestone Americas\nSoftware Engineer\nDecember 2024\xa0-\xa0Present\xa0(1 year 4 months)\nBDIPlus\nFull-stack Developer\nMay  ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4.1", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.5-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4.1", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'Thank you for your question! As of now, I do not hold any patents. My primary focus has been on designing and implementing scalable backend systems, integrations, and solving real-world engineering challenges in production environments. That said, I am always exploring innovative approaches and am open to collaborating on patentable ideas in the future, especially in areas related to distributed systems, observability, or AI-driven solutions.\n\nIf you have any specific ideas or partnership proposals related to innovation or intellectual property, I’d be happy to discuss further.'

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback="The agent correctly states that they do not hold any patents, as no such information is present in the provided context. The response is professional, engaging, and further elaborates on Anup's focus and openness to future innovation, which aligns perfectly with the persona's goal of interacting with potential clients or employers.")

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4.1", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7864
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7864/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
# Passed evaluation - returning reply
